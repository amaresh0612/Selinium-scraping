# %%
import requests
from bs4 import BeautifulSoup
l=[]
base_url = "https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="
for page in range(0,30,10):
    print(base_url+str(page))
    r=requests.get(base_url+str(page))
    c=r.content
    soup=BeautifulSoup(c,"html.parser")
    all = soup.find_all("div", {"class":"propertyRow"})
    for item in all:
        d= {}
        d["Address"]=item.find_all("span", {"class":"propAddressCollapse"})[0].text
        d["Locality"]=item.find_all("span", {"class":"propAddressCollapse"})[1].text
        d["Price"]=item.find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")
        try: 
            d["Beds"]=item.find("span",{"class":"infoBed"}).find("b").text
        except:
            d["Beds"]=None
        try:
            d["Area"]=item.find("span",{"class":"infoSqFt"}).find("b").text
        except:
            d["Area"]=None
        try:
            d["Full Bath"]=item.find("span",{"class":"infoValueFullBath"}).find("b").text
        except:
            d["Full Bath"]=None
        try:
            d["Half Bath"]=item.find("span",{"class":"infoValueHalfBath"}).find("b").text
        except:
            d["Half Bath"]=None
        for colgrp in item.find_all("div",{"class":"columnGroup"}):
            for feature_group, feature_name in zip(colgrp.find_all("span",{"class":"featureGroup"}),colgrp.find_all("span",{"class":"featureName"})):
            #print(feature_group.text, feature_name.text)
                if "Lot Size" in feature_group.text:
                    d["Lot Size"]=feature_name.text
        print("")

        l.append(d)
# Out:
# https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=0
# https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=10
# https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=20

# %%
len(l)
# Out:
# 0

# %%
import pandas as pd

# %%
df= pd.DataFrame(l)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.to_csv("Output.csv")

# %%
import requests
from bs4 import BeautifulSoup

# %%
base_url = "https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="
for page in range(0,30,10):
    print(base_url+str(page)) 
    r=requests.get(base_url+str(page))
    c=r.content
    soup=BeautifulSoup(c,"html.parser")
    print(soup.prettify())
# Out:
# https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=0
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    500: Internal Error - HostGator
#   </title>
#   <meta content="" name="description"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="/img-sys/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/img-sys/css/style.min.css" rel="stylesheet"/>
#   <script async="async" src="/img-sys/js/respond.min.js">
#   </script>
#   <script async="async" src="/img-sys/js/modernizr-2.6.2.min.js">
#   </script>
#  </head>
#  <body>
#   <!--[if lt IE 8]>
# ...

# %%
    all = soup.find_all("div", {"class":"propertyRow"})
    print(all)

# %%
    r=requests.get(base_url+str(page))
    c=r.content
    soup=BeautifulSoup(c,"html.parser")
    print(soup.prettify())

# %%
all[0].find("span",{"class":"infoBed"}).text.replace(NULL, "NA")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-60886baa33d7> in <module>()
# ----> 1 all[0].find("span",{"class":"infoBed"}).text.replace(NULL, "NA")
#
# AttributeError: 'NoneType' object has no attribute 'text'
